# %%
import pandas as pd
df = pd.read_csv('Smoking Data.csv')

# %%
df.head()
# Out:
#       region  age     sex     bmi  children smoker
# 0  southwest   19  female  27.900         0    yes
# 1  southeast   18    male  33.770         1     no
# 2  southeast   28    male  33.000         3     no
# 3  northwest   33    male  22.705         0     no
# 4  northwest   32    male  28.880         0     no

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df.region = le.fit_transform(df['region'])
df.sex = le.fit_transform(df['sex'])

# %%
df
# Out:
#       region  age  sex     bmi  children smoker
# 0          3   19    0  27.900         0    yes
# 1          2   18    1  33.770         1     no
# 2          2   28    1  33.000         3     no
# 3          1   33    1  22.705         0     no
# 4          1   32    1  28.880         0     no
# ...      ...  ...  ...     ...       ...    ...
# 1333       1   50    1  30.970         3     no
# 1334       0   18    0  31.920         0     no
# 1335       2   18    0  36.850         0     no
# 1336       3   21    0  25.800         0     no
# 1337       1   61    0  29.070         0    yes
#
# [1338 rows x 6 columns]

# %%
x = df.drop('smoker',axis=1)
y = df['smoker']

# %%
x.head()
# Out:
#    region  age  sex     bmi  children
# 0       3   19    0  27.900         0
# 1       2   18    1  33.770         1
# 2       2   28    1  33.000         3
# 3       1   33    1  22.705         0
# 4       1   32    1  28.880         0

# %%
y.head()
# Out:
# 0    yes
# 1     no
# 2     no
# 3     no
# 4     no
# Name: smoker, dtype: object

# %%
from sklearn.model_selection import train_test_split as tts

# %%
xtrain , xtest , ytrain, ytest = tts(x,y,train_size=.70,random_state=1)

# %%
xtrain.shape
# Out:
# (936, 5)

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()

# %%
clf.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
predictedValue = clf.predict(xtest)
predictedValue
# Out:
# array(['yes', 'no', 'no', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'yes', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'no',
#        'no', 'no', 'no', 'yes', 'yes', 'no', 'yes', 'no', 'no', 'no',
#        'no', 'no', 'yes', 'no', 'no', 'no', 'no', 'yes', 'no', 'no',
#        'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'no', 'no', 'no',
#        'no', 'no', 'no', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no',
#        'no', 'no', 'no', 'yes', 'no', 'no', 'yes', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'no',
#        'no', 'no', 'no', 'no', 'yes', 'no', 'no', 'no', 'no', 'no', 'yes',
#        'no', 'no', 'yes', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'no',
#        'no', 'no', 'no', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'yes',
# ...

# %%
clf.score(xtest, ytest)
# Out:
# 0.654228855721393

# %%
clf.score(xtrain, ytrain)
# Out:
# 0.9989316239316239

# %%
from sklearn import tree
import matplotlib.pyplot as plt

# %%
tree.plot_tree(clf)
# Out:
# [Text(113.47239525334076, 212.91, 'X[2] <= 0.5\ngini = 0.327\nsamples = 936\nvalue = [743, 193]'),
#  Text(69.2514389615813, 203.85, 'X[3] <= 22.605\ngini = 0.294\nsamples = 457\nvalue = [375, 82]'),
#  Text(17.89576837416481, 194.79, 'X[1] <= 45.0\ngini = 0.449\nsamples = 47\nvalue = [31, 16]'),
#  Text(16.404454342984412, 185.73, 'X[1] <= 38.5\ngini = 0.48\nsamples = 40\nvalue = [24, 16]'),
#  Text(10.439198218262806, 176.67, 'X[3] <= 21.47\ngini = 0.451\nsamples = 35\nvalue = [23, 12]'),
#  Text(4.473942093541202, 167.60999999999999, 'X[4] <= 1.5\ngini = 0.332\nsamples = 19\nvalue = [15, 4]'),
#  Text(2.982628062360802, 158.55, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(5.965256124721604, 158.55, 'X[1] <= 28.0\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(2.982628062360802, 149.49, 'X[3] <= 20.663\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(1.491314031180401, 140.43, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
# ...

# %%
tree.plot_tree(clf,filled=True,rounded=True)
# Out:
# [Text(113.47239525334076, 212.91, 'X[2] <= 0.5\ngini = 0.327\nsamples = 936\nvalue = [743, 193]'),
#  Text(69.2514389615813, 203.85, 'X[3] <= 22.605\ngini = 0.294\nsamples = 457\nvalue = [375, 82]'),
#  Text(17.89576837416481, 194.79, 'X[1] <= 45.0\ngini = 0.449\nsamples = 47\nvalue = [31, 16]'),
#  Text(16.404454342984412, 185.73, 'X[1] <= 38.5\ngini = 0.48\nsamples = 40\nvalue = [24, 16]'),
#  Text(10.439198218262806, 176.67, 'X[3] <= 21.47\ngini = 0.451\nsamples = 35\nvalue = [23, 12]'),
#  Text(4.473942093541202, 167.60999999999999, 'X[4] <= 1.5\ngini = 0.332\nsamples = 19\nvalue = [15, 4]'),
#  Text(2.982628062360802, 158.55, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(5.965256124721604, 158.55, 'X[1] <= 28.0\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(2.982628062360802, 149.49, 'X[3] <= 20.663\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(1.491314031180401, 140.43, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
# ...

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(clf,filled=True,rounded=True,feature_names=x.columns)
# Out:
# [Text(283.6809881333519, 532.275, 'sex <= 0.5\ngini = 0.327\nsamples = 936\nvalue = [743, 193]'),
#  Text(173.12859740395322, 509.625, 'bmi <= 22.605\ngini = 0.294\nsamples = 457\nvalue = [375, 82]'),
#  Text(44.73942093541203, 486.975, 'age <= 45.0\ngini = 0.449\nsamples = 47\nvalue = [31, 16]'),
#  Text(41.01113585746102, 464.32500000000005, 'age <= 38.5\ngini = 0.48\nsamples = 40\nvalue = [24, 16]'),
#  Text(26.097995545657014, 441.675, 'bmi <= 21.47\ngini = 0.451\nsamples = 35\nvalue = [23, 12]'),
#  Text(11.184855233853007, 419.025, 'children <= 1.5\ngini = 0.332\nsamples = 19\nvalue = [15, 4]'),
#  Text(7.456570155902004, 396.375, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(14.913140311804009, 396.375, 'age <= 28.0\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(7.456570155902004, 373.725, 'bmi <= 20.663\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(3.728285077951002, 351.07500000000005, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
# ...

# %%
import numpy as np
np.array(ytest)
# Out:
# array(['no', 'no', 'no', 'no', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes',
#        'yes', 'yes', 'no', 'yes', 'yes', 'no', 'yes', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'yes', 'no', 'no', 'no', 'no', 'no', 'no',
#        'yes', 'no', 'yes', 'no', 'no', 'no', 'no', 'no', 'yes', 'no',
#        'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'no', 'no',
#        'no', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes',
#        'yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'no', 'no',
#        'yes', 'yes', 'no', 'yes', 'no', 'no', 'yes', 'no', 'no', 'no',
# ...

# %%
clf.score(xtest, ytest)
# Out:
# 0.654228855721393

# %%
from sklearn.metrics import classification_report , confusion_matrix, roc_curve, plot_roc_curve

# %%
classification_report(ytest , predictedValue)
# Out:
# '              precision    recall  f1-score   support\n\n          no       0.79      0.77      0.78       321\n         yes       0.18      0.20      0.19        81\n\n    accuracy                           0.65       402\n   macro avg       0.48      0.48      0.48       402\nweighted avg       0.67      0.65      0.66       402\n'

# %%
print(classification_report(ytest , predictedValue))
# Out:
#               precision    recall  f1-score   support
#
#           no       0.79      0.77      0.78       321
#          yes       0.18      0.20      0.19        81
#
#     accuracy                           0.65       402
#    macro avg       0.48      0.48      0.48       402
# weighted avg       0.67      0.65      0.66       402

# %%
confusion_matrix(ytest ,predictedValue)
# Out:
# array([[247,  74],
#        [ 65,  16]], dtype=int64)

# %%
con_mat = confusion_matrix(ytest ,predictedValue)

# %%
con_mat
# Out:
# array([[247,  74],
#        [ 65,  16]], dtype=int64)

# %%
import seaborn as sns
sns.heatmap(con_mat, annot=True)
# Out:
# <AxesSubplot:>

# %%
tp,fn,fp,tn=confusion_matrix(ytest ,predictedValue).reshape(-1)

# %%
tp
# Out:
# 247

# %%
fn
# Out:
# 74

# %%
fp
# Out:
# 65

# %%
tn
# Out:
# 16

# %%
(tp+tn) / (tp+tn+fp+fn)
# Out:
# 0.654228855721393

# %%
plot_roc_curve(clf,xtest,ytest)

# %%
import matplotlib.pyplot as plt
#plot_roc_curve(clf,xtest,ytest)
plt.plot([0,1],[0,1])

# %%
import matplotlib.pyplot as plt
plot_roc_curve(clf,xtest,ytest)
plt.plot([0,1],[0,1])
